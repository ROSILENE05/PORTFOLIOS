# %% [markdown]
# # ANALISE DE DADOS DA EDUCAÇÃO INTELIGENTE - API
# # SÃO DADOS DO INEP DISPONIBILIZADO POR MEIO DE API
#
# # NÃO CONSEGUI ABRIR O SITE

# %%
# Importando as Bibliotecas
import pandas as pd

# importa as requisições
import requests

# URL de acesso a API
# url ="educacao.dadosabertosbr.com/buscaavancada/api..."

# Requisição os dados da API
# resposta = request.get(url)

# Criando o Dataframe
# df = pd.Dataframe(resposta.json()[1])

# df.head()

# %%
# qual o tamanho do Dataframe
# df.shape
# df.value_counts()

# %%
# Em qual estados estão essas escolas?
# df["estado"].value_counts()

# %%
# São todas escolas municipais?
# df["dependenciaadministrativatxt"].value_counts()
