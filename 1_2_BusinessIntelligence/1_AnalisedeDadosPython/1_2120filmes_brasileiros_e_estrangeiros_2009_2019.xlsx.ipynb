# %% [markdown]
# #  ÁNALISE DE DADOS DE FILMES EXBIDOS NO BRASIL.
#
# # Com base nos dados da Ancine.

# %% [markdown]
# # REQUISITOS:
# # 1-
# # 2-
# # 3-
# # 4-
# # 5-
# # 6-

# %%
import pandas as pd
# %matplotlib inline

# %%
# criando o Dataframe com arquivo excel
# é preciso pular as das primeiras linhas (skiprows)
df = pd.read_excel("1_2120filmes_brasileiros_e_estrangeiros_2009_2019.xlsx" , skiprows=2, skipfooter=20)
#Exibe as 5 primeiras linhas do dataframe
df.head(5)
# Out:
#    Ano de exibição              Título da obra         CPB/ROE    Gênero  \
# 0             2019   120 Batimentos Por Minuto  E1700453800000    Ficção
# 1             2019                     3 Faces  E1800494900000    Ficção
# 2             2019            45 Dias Sem Você  B1800586000000    Ficção
# 3             2019    A 100 Passos De Um Sonho  E1402795100000    Ficção
# 4             2019  A Abelhinha Maya - O Filme  E1800136100000  Animação
#
#   País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 0                        França           Estrangeira              43104
# 1                           Irã           Estrangeira              43559
# 2                        Brasil            Brasileira              43601
# 3                Estados Unidos           Estrangeira              41879
# 4                      Alemanha           Estrangeira              43237
#
#   Empresa distribuidora Origem da empresa distribuidora  \
# ...

# %%
# Exibindo as 5 ultimas linhas
df.tail()
# Out:
#       Ano de exibição       Título da obra         CPB/ROE        Gênero  \
# 7076             2009          Xuxa Gêmeas  B0600616500000        Ficção
# 7077             2009         Zico na Rede  B0901041400000  Documentário
# 7078             2009             À Deriva  B0901015000000        Ficção
# 7079             2009     É Proibido Fumar  B0901108700000        Ficção
# 7080             2009  Última Parada - 174  B0800914800000        Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 7076                        Brasil            Brasileira              39066
# 7077                        Brasil            Brasileira              39997
# 7078        Brasil, Estados Unidos            Brasileira              40025
# 7079                        Brasil            Brasileira              40151
# 7080                        Brasil            Brasileira              39745
#
#      Empresa distribuidora Origem da empresa distribuidora  \
# ...

# %%
# OBS: NaN - significa para o pandas que não é números, é um campo vazio. Tem que abrir o arquivo
# dando o comando para verificar as 20 ultimas linhas do arquivo.
df.tail(21)
# Out:
#       Ano de exibição                   Título da obra         CPB/ROE  \
# 7060             2009         Vicky Cristina Barcelona  E1500741400000
# 7061             2009                       Vigaristas  E1500623800000
# 7062             2009                          Vila 21  E1600637700000
# 7063             2009               Violência Gratuita  E1600584300000
# 7064             2009                            Vitus  E1600639100000
# 7065             2009                         Viva Voz  B0300007100000
# 7066             2009                Você é tão Bonito  E1600592600000
# 7067             2009                  Vocês, os Vivos  E1600637600000
# 7068             2009                           Volver  E1600639300000
# 7069             2009                               W.  E1600639400000
# 7070             2009   Waldick, Sempre no meu Coração  B0800852600000
# 7071             2009                           Wall-E  E1500366400000
# ...

# %%
# Esse comando tem que ser colocado no mesmo arquivo sendo no começo acrescentando (skipfooter), como está no arquivo seguinte:
#df = pd.read_excel("1_2120filmes_brasileiros_e_estrangeiros_2009_2019.xlsx" , skiprows=2, skipfooter=20)
# Esse comando vai retirar essas linhas com NaN.

# %%
# Verificar todos os tipos das colunas
df.dtypes
# Out:
# Ano de exibição                     int64
# Título da obra                     object
# CPB/ROE                            object
# Gênero                             object
# País(es) produtor(es) da obra      object
# Nacionalidade da obra              object
# Data de lançamento                 object
# Empresa distribuidora              object
# Origem da empresa distribuidora    object
# Público no ano de exibição         object
# Renda (R$) no ano de exibição      object
# dtype: object

# %%
# Converter campo data de lançamento em data
# df["Data de lançamento"] = pd.to_datetime(df["Data de lançamento"])

# %%
#Vamos tentar identificar o problema da coluna data de lançamento
df["Data de lançamento"].value_counts()
# Out:
# Relançamento    198
# 41264            33
# 42341            33
# 41607            29
# 41215            27
#                ...
# 41913             1
# 43574             1
# 40621             1
# 41922             1
# 41406             1
# Name: Data de lançamento, Length: 878, dtype: int64

# %%
# Exibir alguns filmes que estão com data de relançamento
df[df["Data de lançamento"] == "Relançamento"].head()
# Out:
#      Ano de exibição                        Título da obra         CPB/ROE  \
# 6               2019                       A Bela da Tarde  E1700492900000
# 278             2019                    Gritos e Sussurros  E1600273100000
# 359             2019                                Matrix  E1500096600000
# 390             2019                   Morangos Silvestres  E1500804700000
# 396             2019  Mulholland Drive - Cidade dos Sonhos  E1700486000000
#
#      Gênero País(es) produtor(es) da obra Nacionalidade da obra  \
# 6    Ficção                França, Itália           Estrangeira
# 278  Ficção                        Suécia           Estrangeira
# 359  Ficção     Austrália, Estados Unidos           Estrangeira
# 390  Ficção                        Suécia           Estrangeira
# 396  Ficção        Estados Unidos, França           Estrangeira
#
#     Data de lançamento Empresa distribuidora Origem da empresa distribuidora  \
# ...

# %% [markdown]
# ## Decisão sobre dados incorretos /faltantes/divergentes

# %%
# Para verificar quantidade o tamanho do dataframe(linhas, colunas)
df.shape
# Out:
# (7081, 11)

# %%
#Criar um novo dataframe sem os relançamentos
# O comando copy é para fazer uma copia do dataframe
# df_novo é o dataframe original

df_novo = df[df["Data de lançamento"] != "Relançamento"].copy()

# %%
# Vmaos verificar os tipos das colunas
df_novo.dtypes
# Out:
# Ano de exibição                     int64
# Título da obra                     object
# CPB/ROE                            object
# Gênero                             object
# País(es) produtor(es) da obra      object
# Nacionalidade da obra              object
# Data de lançamento                 object
# Empresa distribuidora              object
# Origem da empresa distribuidora    object
# Público no ano de exibição         object
# Renda (R$) no ano de exibição      object
# dtype: object

# %%
# Converter a coluna Data de lançamento para datetime
# df_novo["Data de lançamento"] = pd.to_datetime(df_novo["Data de lançamento"])

# %%
df_novo.dtypes
# Out:
# Ano de exibição                     int64
# Título da obra                     object
# CPB/ROE                            object
# Gênero                             object
# País(es) produtor(es) da obra      object
# Nacionalidade da obra              object
# Data de lançamento                 object
# Empresa distribuidora              object
# Origem da empresa distribuidora    object
# Público no ano de exibição         object
# Renda (R$) no ano de exibição      object
# dtype: object

# %%
# Quais os anos mais filmes lançados?
# df_novo["Data de lançamento"].dt.year.value_counts()

# %%
# Com esse comando pode criar o grafico de data e ano
# df_novo["Data de lançamento"].dt.year.value_counts().plot.bar()

# %%
# Qual o filme com maior bilheteria?
# df_novo[df_novo["Renda (R$) no ano de exibição"] == df_novo["Renda (R$) no ano de exibição"].max()]

# %%
# df_novo.nlargest(3, "Renda (R$) no ano de exibição")

# %%
# Qual o filme de menor bilheteria?
# df_novo[df_novo["Renda (R$) no ano de exibição"] == df_novo["Renda (R$) no ano de exibição"].min()]

# %%
# Quantos filmes Brasileiros e estrangeiros
df_novo["Nacionalidade da obra"].value_counts()
# Out:
# Estrangeira    4767
# Brasileira     2116
# Name: Nacionalidade da obra, dtype: int64

# %%
df_novo["Nacionalidade da obra"].value_counts().plot.bar()
